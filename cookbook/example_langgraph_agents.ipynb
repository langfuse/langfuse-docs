# %% [markdown]
# <!-- NOTEBOOK_METADATA source: "Jupyter Notebook" title: "Example - Trace and Evaluate LangGraph Agents" description: "This guide shows how to evaluate LangGraph Agents with Langfuse using online and offline evaluation methods." category: "Integrations" -->
#
# # Evaluate LangGraph Agents
#
# In this tutorial, we will learn how to **monitor the internal steps (traces) of [LangGraph agents](https://github.com/langchain-ai/langgraph)** and **evaluate its performance** using [Langfuse](https://langfuse.com) and [Hugging Face Datasets](https://huggingface.co/datasets).
#
# This guide covers **online** and **offline** evaluation metrics used by teams to bring agents to production fast and reliably. To learn more about evaluation strategies, check out our [blog post](https://langfuse.com/blog/2025-03-04-llm-evaluation-101-best-practices-and-challenges).
#
# **Why AI agent Evaluation is important:**
# - Debugging issues when tasks fail or produce suboptimal results
# - Monitoring costs and performance in real-time
# - Improving reliability and safety through continuous feedback

# %% [markdown]
# ## Step 0: Install the Required Libraries
#
# Below we install the `langgraph` library, `langfuse` and the Hugging Face `datasets` library

# %%
# %pip install langfuse langchain langgraph langchain_openai langchain_community langchain_huggingface -q

# %% [markdown]
# ## Step 1: Set Environment Variables
#
# Get your Langfuse API keys by signing up for Langfuse cloud or self-hosting Langfuse.

# %%
import os

# Get keys for your project from the project settings page: https://cloud.langfuse.com
os.environ["LANGFUSE_PUBLIC_KEY"] = "pk-lf-***" 
os.environ["LANGFUSE_SECRET_KEY"] = "sk-lf-***" 
os.environ["LANGFUSE_BASE_URL"] = "https://cloud.langfuse.com" # 🇪🇺 EU region
# os.environ["LANGFUSE_BASE_URL"] = "https://us.cloud.langfuse.com" # 🇺🇸 US region

# Your openai key
os.environ["OPENAI_API_KEY"] = "sk-proj-***"

# %% [markdown]
# With the environment variables set, we can now initialize the Langfuse client. get_client() initializes the Langfuse client using the credentials provided in the environment variables.

# %%
from langfuse import get_client
 
langfuse = get_client()
 
# Verify connection
if langfuse.auth_check():
    print("Langfuse client is authenticated and ready!")
else:
    print("Authentication failed. Please check your credentials and host.")
# Out:
# Langfuse client is authenticated and ready!

# %% [markdown]
# ## Step 2: Test Your Instrumentation
#
# Here is a simple Q&A agent. We run it to confirm that the instrumentation is working correctly. If everything is set up correctly, you will see logs/spans in your observability dashboard.

# %%
from typing import Annotated
 
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from typing_extensions import TypedDict
 
from langgraph.graph import StateGraph
from langgraph.graph.message import add_messages
 
class State(TypedDict):
    # Messages have the type "list". The `add_messages` function in the annotation defines how this state key should be updated
    # (in this case, it appends messages to the list, rather than overwriting them)
    messages: Annotated[list, add_messages]
 
graph_builder = StateGraph(State)
 
llm = ChatOpenAI(model = "gpt-4o", temperature = 0.2)
 
# The chatbot node function takes the current State as input and returns an updated messages list. This is the basic pattern for all LangGraph node functions.
def chatbot(state: State):
    return {"messages": [llm.invoke(state["messages"])]}
 
# Add a "chatbot" node. Nodes represent units of work. They are typically regular python functions.
graph_builder.add_node("chatbot", chatbot)
 
# Add an entry point. This tells our graph where to start its work each time we run it.
graph_builder.set_entry_point("chatbot")
 
# Set a finish point. This instructs the graph "any time this node is run, you can exit."
graph_builder.set_finish_point("chatbot")
 
# To be able to run our graph, call "compile()" on the graph builder. This creates a "CompiledGraph" we can use invoke on our state.
graph = graph_builder.compile()

# %%
from langfuse.langchain import CallbackHandler

# Initialize Langfuse CallbackHandler for Langchain (tracing)
langfuse_handler = CallbackHandler()
 
for s in graph.stream(
    {"messages": [HumanMessage(content = "What is Langfuse?")]},
    config={"callbacks": [langfuse_handler]}):
    print(s)

# %% [markdown]
# Check your Langfuse Traces Dashboard to confirm that the spans and logs have been recorded.
#
# Example trace in Langfuse:
#
# ![Example trace in Langfuse](https://langfuse.com/images/cookbook/example-langgraph-evaluation/first-example-trace.png)
#
# _[Link to the trace](https://cloud.langfuse.com/project/cloramnkj0002jz088vzn1ja4/traces/ed0970b5-b251-4b85-9023-c0ed81462510?timestamp=2025-03-20T13%3A44%3A44.381Z&display=details&observation=0731595f-06e4-4f5a-b535-6e09677a752d)_

# %% [markdown]
# ## Step 3: Observe and Evaluate a More Complex Agent
#
# Now that you have confirmed your instrumentation works, let's try a more complex query so we can see how advanced metrics (token usage, latency, costs, etc.) are tracked.

# %%
import os
from typing import TypedDict, List, Dict, Any, Optional
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

# %%
class EmailState(TypedDict):
    email: Dict[str, Any]           
    is_spam: Optional[bool]         
    spam_reason: Optional[str]      
    email_category: Optional[str]   
    draft_response: Optional[str]   
    messages: List[Dict[str, Any]]

# %%
# Initialize LLM
model = ChatOpenAI( model="gpt-4o",temperature=0)

class EmailState(TypedDict):
    email: Dict[str, Any]
    is_spam: Optional[bool]
    draft_response: Optional[str]
    messages: List[Dict[str, Any]]

# Define nodes
def read_email(state: EmailState):
    email = state["email"]
    print(f"Alfred is processing an email from {email['sender']} with subject: {email['subject']}")
    return {}

def classify_email(state: EmailState):
    email = state["email"]
    
    prompt = f"""
As Alfred the butler of Mr wayne and it's SECRET identity Batman, analyze this email and determine if it is spam or legitimate and should be brought to Mr wayne's attention.

Email:
From: {email['sender']}
Subject: {email['subject']}
Body: {email['body']}

First, determine if this email is spam.
answer with SPAM or HAM if it's legitimate. Only return the answer
Answer :
    """
    messages = [HumanMessage(content=prompt)]
    response = model.invoke(messages)
    
    response_text = response.content.lower()
    print(response_text)
    is_spam = "spam" in response_text and "ham" not in response_text
    
    if not is_spam:
        new_messages = state.get("messages", []) + [
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": response.content}
        ]
    else :
        new_messages = state.get("messages", [])
    
    return {
        "is_spam": is_spam,
        "messages": new_messages
    }

def handle_spam(state: EmailState):
    print(f"Alfred has marked the email as spam.")
    print("The email has been moved to the spam folder.")
    return {}

def drafting_response(state: EmailState):
    email = state["email"]
    
    prompt = f"""
As Alfred the butler, draft a polite preliminary response to this email.

Email:
From: {email['sender']}
Subject: {email['subject']}
Body: {email['body']}

Draft a brief, professional response that Mr. Wayne can review and personalize before sending.
    """
    
    messages = [HumanMessage(content=prompt)]
    response = model.invoke(messages)
    
    new_messages = state.get("messages", []) + [
        {"role": "user", "content": prompt},
        {"role": "assistant", "content": response.content}
    ]
    
    return {
        "draft_response": response.content,
        "messages": new_messages
    }

def notify_mr_wayne(state: EmailState):
    email = state["email"]
    
    print("\n" + "="*50)
    print(f"Sir, you've received an email from {email['sender']}.")
    print(f"Subject: {email['subject']}")
    print("\nI've prepared a draft response for your review:")
    print("-"*50)
    print(state["draft_response"])
    print("="*50 + "\n")
    
    return {}

# Define routing logic
def route_email(state: EmailState) -> str:
    if state["is_spam"]:
        return "spam"
    else:
        return "legitimate"

# Create the graph
email_graph = StateGraph(EmailState)

# Add nodes
email_graph.add_node("read_email", read_email) # the read_email node executes the read_mail function
email_graph.add_node("classify_email", classify_email) # the classify_email node will execute the classify_email function
email_graph.add_node("handle_spam", handle_spam) #same logic 
email_graph.add_node("drafting_response", drafting_response) #same logic
email_graph.add_node("notify_mr_wayne", notify_mr_wayne) # same logic

# %%
# Add edges
email_graph.add_edge(START, "read_email") # After starting we go to the "read_email" node

email_graph.add_edge("read_email", "classify_email") # after_reading we classify

# Add conditional edges
email_graph.add_conditional_edges(
    "classify_email", # after classify, we run the "route_email" function"
    route_email,
    {
        "spam": "handle_spam", # if it return "Spam", we go the "handle_span" node
        "legitimate": "drafting_response" # and if it's legitimate, we go to the "drafting response" node
    }
)

# Add final edges
email_graph.add_edge("handle_spam", END) # after handling spam we always end
email_graph.add_edge("drafting_response", "notify_mr_wayne")
email_graph.add_edge("notify_mr_wayne", END) # after notifyinf Me wayne, we can end  too

# %%
# Compile the graph
compiled_graph = email_graph.compile()

# %%
 # Example emails for testing
legitimate_email = {
    "sender": "Joker",
    "subject": "Found you Batman ! ",
    "body": "Mr. Wayne,I found your secret identity ! I know you're batman ! Ther's no denying it, I have proof of that and I'm coming to find you soon. I'll get my revenge. JOKER"
}

spam_email = {
    "sender": "Crypto bro",
    "subject": "The best investment of 2025",
    "body": "Mr Wayne, I just launched an ALT coin and want you to buy some !"
}

# %%
from langfuse.langchain import CallbackHandler

# Initialize Langfuse CallbackHandler for Langchain (tracing)
langfuse_handler = CallbackHandler()

# Process legitimate email
print("\nProcessing legitimate email...")
legitimate_result = compiled_graph.invoke(
    input = {
        "email": legitimate_email,
        "is_spam": None,
        "draft_response": None,
        "messages": []
        },
    config={"callbacks": [langfuse_handler]}
)

# Process spam email
print("\nProcessing spam email...")
spam_result = compiled_graph.invoke(
    input = {
        "email": spam_email,
        "is_spam": None,
        "draft_response": None,
        "messages": []
        },
    config={"callbacks": [langfuse_handler]}
)

# %% [markdown]
# ### Trace Structure
#
# Langfuse records a **trace** that contains **spans**, which represent each step of your agent’s logic. Here, the trace contains the overall agent run and sub-spans for:
# - The tool call (get_weather)
# - The LLM calls (Responses API with 'gpt-4o')
#
# You can inspect these to see precisely where time is spent, how many tokens are used, and so on:
#
# ![Trace tree in Langfuse](https://langfuse.com/images/cookbook/example-langgraph-evaluation/trace-tree.png)
#
# _[Link to the trace](https://cloud.langfuse.com/project/cloramnkj0002jz088vzn1ja4/traces/3dd76e4b-980c-40eb-ae6d-ba9db5f6a349?timestamp=2025-03-20T14%3A56%3A16.665Z&display=details&observation=22b11054-93a8-4ff9-b862-babfcee906ec)_

# %% [markdown]
# ## Online Evaluation
#
# Online Evaluation refers to evaluating the agent in a live, real-world environment, i.e. during actual usage in production. This involves monitoring the agent’s performance on real user interactions and analyzing outcomes continuously.
#
# We have written down a guide on different evaluation techniques [here](https://langfuse.com/blog/2025-03-04-llm-evaluation-101-best-practices-and-challenges).
#
# ### Common Metrics to Track in Production
#
# 1. **Costs** — The instrumentation captures token usage, which you can transform into approximate costs by assigning a price per token.
# 2. **Latency** — Observe the time it takes to complete each step, or the entire run.
# 3. **User Feedback** — Users can provide direct feedback (thumbs up/down) to help refine or correct the agent.
# 4. **LLM-as-a-Judge** — Use a separate LLM to evaluate your agent’s output in near real-time (e.g., checking for toxicity or correctness).
#
# Below, we show examples of these metrics.

# %% [markdown]
# #### 1. Costs
#
# Below is a screenshot showing usage for `gpt-4o` calls. This is useful to see costly steps and optimize your agent.
#
# ![Costs](https://langfuse.com/images/cookbook/example-langgraph-evaluation/gpt-4o-costs.png)
#
# _[Link to the trace](https://cloud.langfuse.com/project/cloramnkj0002jz088vzn1ja4/traces/3dd76e4b-980c-40eb-ae6d-ba9db5f6a349?timestamp=2025-03-20T14%3A56%3A16.665Z&display=details&observation=22b11054-93a8-4ff9-b862-babfcee906ec)_

# %% [markdown]
# #### 2. Latency
#
# We can also see how long it took to complete each step. In the example below, the entire run took about 3 seconds, which you can break down by step. This helps you identify bottlenecks and optimize your agent.
#
# ![Latency](https://langfuse.com/images/cookbook/example-langgraph-evaluation/agent-latency.png)
#
# _[Link to the trace](https://cloud.langfuse.com/project/cloramnkj0002jz088vzn1ja4/traces/3dd76e4b-980c-40eb-ae6d-ba9db5f6a349?timestamp=2025-03-20T14%3A56%3A16.665Z&display=timeline)_

# %% [markdown]
# #### 3. User Feedback
#
# If your agent is embedded into a user interface, you can record direct user feedback (like a thumbs-up/down in a chat UI).

# %%
from langfuse import get_client
 
langfuse = get_client()
 
# Option 1: Use the yielded span object from the context manager
with langfuse.start_as_current_observation(
    as_type="span",
    name="langgraph-request") as span:
    # ... LangGraph execution ...
 
    # Score using the span object
    span.score_trace(
        name="user-feedback",
        value=1,
        data_type="NUMERIC",
        comment="This was correct, thank you"
    )
 
# Option 2: Use langfuse.score_current_trace() if still in context
with langfuse.start_as_current_observation(as_type="span", name="langgraph-request") as span:
    # ... LangGraph execution ...
 
    # Score using current context
    langfuse.score_current_trace(
        name="user-feedback",
        value=1,
        data_type="NUMERIC"
    )
 
# Option 3: Use create_score() with trace ID (when outside context)
langfuse.create_score(
    trace_id="predefined-trace-id", # Needs to be a valid trace id format (see docs)
    name="user-feedback",
    value=1,
    data_type="NUMERIC",
    comment="This was correct, thank you"
)

# %% [markdown]
# User feedback is then captured in Langfuse:
#
# ![User feedback is being captured in Langfuse](https://langfuse.com/images/cookbook/example-langgraph-evaluation/user-feedback.png)

# %% [markdown]
# #### 4. Automated LLM-as-a-Judge Scoring
#
# LLM-as-a-Judge is another way to automatically evaluate your agent's output. You can set up a separate LLM call to gauge the output’s correctness, toxicity, style, or any other criteria you care about.
#
# **Workflow**:
# 1. You define an **Evaluation Template**, e.g., "Check if the text is toxic."
# 2. You set a model that is used as judge-model; in this case `gpt-4o-mini`.
# 2. Each time your agent generates output, you pass that output to your "judge" LLM with the template.
# 3. The judge LLM responds with a rating or label that you log to your observability tool.
#
# Example from Langfuse:
#
# ![LLM-as-a-Judge Evaluation Template](https://langfuse.com/images/cookbook/integration_openai-agents/evaluator-template.png)
# ![LLM-as-a-Judge Evaluator](https://langfuse.com/images/cookbook/integration_openai-agents/evaluator.png)

# %%
# Process spam email
print("\nProcessing spam email...")
spam_result = compiled_graph.invoke(
    input = {
        "email": spam_email,
        "is_spam": None,
        "draft_response": None,
        "messages": []
        },
    config={"callbacks": [langfuse_handler]}
)

# %% [raw]
# Processing spam email...
# Alfred is processing an email from Crypto bro with subject: The best investment of 2025
# spam
# Alfred has marked the email as spam.
# The email has been moved to the spam folder.

# %% [markdown]
# You can see that the answer of this example is judged as "not toxic".
#
# ![LLM-as-a-Judge Evaluation Score](https://langfuse.com/images/cookbook/example-langgraph-evaluation/llm-as-a-judge-score.png)

# %% [markdown]
# #### 5. Observability Metrics Overview
#
# All of these metrics can be visualized together in dashboards. This enables you to quickly see how your agent performs across many sessions and helps you to track quality metrics over time.
#
# ![Observability metrics overview](https://langfuse.com/images/cookbook/integration_openai-agents/dashboard-dark.png)

# %% [markdown]
# ## Offline Evaluation
#
# Online evaluation is essential for live feedback, but you also need **offline evaluation**—systematic checks before or during development. This helps maintain quality and reliability before rolling changes into production.

# %% [markdown]
# ### Dataset Evaluation
#
# In offline evaluation, you typically:
# 1. Have a benchmark dataset (with prompt and expected output pairs)
# 2. Run your agent on that dataset
# 3. Compare outputs to the expected results or use an additional scoring mechanism
#
# Below, we demonstrate this approach with the [q&a-dataset](https://huggingface.co/datasets/junzhang1207/search-dataset), which contains questions and expected answers.

# %%
import pandas as pd
from datasets import load_dataset
 
# Fetch search-dataset from Hugging Face
dataset = load_dataset("junzhang1207/search-dataset", split = "train")
df = pd.DataFrame(dataset)
print("First few rows of search-dataset:")
print(df.head())

# %% [markdown]
# Next, we create a dataset entity in Langfuse to track the runs. Then, we add each item from the dataset to the system.

# %%
from langfuse import Langfuse
langfuse = Langfuse()
 
langfuse_dataset_name = "qa-dataset_langgraph-agent"
 
# Create a dataset in Langfuse
langfuse.create_dataset(
    name=langfuse_dataset_name,
    description="q&a dataset uploaded from Hugging Face",
    metadata={
        "date": "2025-03-21",
        "type": "benchmark"
    }
)

# %%
df_30 = df.sample(30) # For this example, we upload only 30 dataset questions

for idx, row in df_30.iterrows():
    langfuse.create_dataset_item(
        dataset_name=langfuse_dataset_name,
        input={"text": row["question"]},
        expected_output={"text": row["expected_answer"]}
    )

# %% [markdown]
# ![Dataset items in Langfuse](https://langfuse.com/images/cookbook/example-langgraph-evaluation/example-dataset.png)

# %% [markdown]
# #### Running the Agent on the Dataset
#
# First, we define a task function `my_task()` that wraps our LangGraph agent.

# %%
from langfuse import get_client
from langfuse.langchain import CallbackHandler
from langchain_openai import ChatOpenAI
from langgraph.graph.message import add_messages
from langgraph.graph import StateGraph
from langchain_core.messages import HumanMessage
from typing import Annotated
from typing_extensions import TypedDict

# Initialize Langfuse CallbackHandler for Langchain
langfuse = get_client()
langfuse_handler = CallbackHandler()

# Define the task function we pass to the experiment runner method
def my_task(*, item, **kwargs):
    
    question = item.input["text"]
    
    class State(TypedDict):
        messages: Annotated[list, add_messages]
 
    graph_builder = StateGraph(State)
    llm = ChatOpenAI(model = "gpt-4o")

    def chatbot(state: State):
        return {"messages": [llm.invoke(state["messages"])]}
    
    graph_builder.add_node("chatbot", chatbot)
    graph_builder.set_entry_point("chatbot")
    graph_builder.set_finish_point("chatbot")
    graph = graph_builder.compile()

    response = graph.invoke(
        input={"messages": [HumanMessage(content=question)]},
        config={"callbacks": [langfuse_handler]}
        )
        
    print(question)
    print(response["messages"][1].content)

    return response["messages"][1].content

# %% [markdown]
# Finally, we use the experiment runner SDK to run our task function against each dataset item. The experiment runner handles concurrent execution, automatic tracing, and evaluation.

# %%
# Fetch dataset and run experiment
dataset = langfuse.get_dataset('qa-dataset_langgraph-agent')

result = dataset.run_experiment(
    name="run_gpt-4o",
    description="My first run",
    task=my_task,
    metadata={"model": "gpt-4o"}
)
 
# Flush the langfuse client to ensure all data is sent to the server at the end of the experiment run
langfuse.flush()
print(result.format())
# Out:
# michelangelo david height in meteres
# Michelangelo's David stands approximately 5.17 meters tall.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 # Fetch dataset and run experiment
#       2 dataset = langfuse.get_dataset('qa-dataset_langgraph-agent')
# ----> 4 result = dataset.run_experiment(
#       5     name="run_gpt-4o",
#       6     description="My first run",
#       7     task=my_task,
#       8     metadata={"model": "gpt-4o"}
#       9 )
#      11 # Flush the langfuse client to ensure all data is sent to the server at the end of the experiment run
#      12 langfuse.flush()
#
# File ~/Documents/GitHub/langfuse-docs/.venv/lib/python3.13/site-packages/langfuse/_client/datasets.py:413, in DatasetClient.run_experiment(self, name, run_name, description, task, evaluators, composite_evaluator, run_evaluators, max_concurrency, metadata)
#     410 if not langfuse_client:
#     411     raise ValueError("No Langfuse client available. Dataset items are empty.")
# --> 413 return langfuse_client.run_experiment(
#     414     name=name,
#     415     run_name=run_name,
#     416     description=description,
#     417     data=self.items,
#     418     task=task,
#     419     evaluators=evaluators,
#     420     composite_evaluator=composite_evaluator,
#     421     run_evaluators=run_evaluators,
#     422     max_concurrency=max_concurrency,
#     423     metadata=metadata,
#     424 )
#
# File ~/Documents/GitHub/langfuse-docs/.venv/lib/python3.13/site-packages/langfuse/_client/client.py:2717, in Langfuse.run_experiment(self, name, run_name, description, data, task, evaluators, composite_evaluator, run_evaluators, max_concurrency, metadata)
#    2541 def run_experiment(
#    2542     self,
#    2543     *,
#    (...)   2553     metadata: Optional[Dict[str, str]] = None,
#    2554 ) -> ExperimentResult:
#    2555     """Run an experiment on a dataset with automatic tracing and evaluation.
#    2556
#    2557     This method executes a task function on each item in the provided dataset,
#    (...)   2713         - Async execution is handled automatically with smart event loop detection
#    2714     """
#    2715     return cast(
#    2716         ExperimentResult,
# -> 2717         run_async_safely(
#    2718             self._run_experiment_async(
#    2719                 name=name,
#    2720                 run_name=self._create_experiment_run_name(
#    2721                     name=name, run_name=run_name
#    2722                 ),
#    2723                 description=description,
#    2724                 data=data,
#    2725                 task=task,
#    2726                 evaluators=evaluators or [],
#    2727                 composite_evaluator=composite_evaluator,
#    2728                 run_evaluators=run_evaluators or [],
#    2729                 max_concurrency=max_concurrency,
#    2730                 metadata=metadata,
#    2731             ),
#    2732         ),
#    2733     )
#
# File ~/Documents/GitHub/langfuse-docs/.venv/lib/python3.13/site-packages/langfuse/_client/utils.py:121, in run_async_safely(coro)
#     119 thread = _RunAsyncThread(coro)
#     120 thread.start()
# --> 121 thread.join()
#     123 if thread.exception:
#     124     raise thread.exception
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py:1092, in Thread.join(self, timeout)
#    1089 if timeout is not None:
#    1090     timeout = max(timeout, 0)
# -> 1092 self._handle.join(timeout)
#
# KeyboardInterrupt:
# locations where wild cyan red-crowned parakeets can be found
# The wild cyan red-crowned parakeet, also known as the cyan mutation of the red-crowned parakeet or cyan kākāriki, is a color mutation of the red-crowned parakeet that can be found in New Zealand. The red-crowned parakeet, or kākāriki, primarily inhabits a variety of locations within New Zealand, including:
#
# 1. **Offshore Islands**: They are commonly found on several predator-free offshore islands where conservation efforts are more easily managed. Some of these islands include Kapiti Island, Little Barrier Island (Hauturu), and the Hen and Chickens Islands.
#
# 2. **Mainland Sanctuaries**: Successful conservation efforts have also established populations in mainland sanctuaries such as the Zealandia Ecosanctuary in Wellington and the Otari-Wilton's Bush.
#
# 3. **Stewart Island/Rakiura**: The birds are also present on Stewart Island and some of its smaller surrounding islands.
#
# 4. **Fiordland**: Parts of the Fiordland region also house wild populations, particularly in areas with effective predator control.
#
# Wild populations of the rare cyan color mutation would be subject to the same habitat locations as the typical red-crowned parakeets. However, the mutation is more likely to occur in captivity and managed breeding programs than in widespread wild populations, due to its rarity and the specific genetic conditions required for its appearance. Conservation and careful management are essential for maintaining these populations.
# When did Virgin Atlantic drop its Hong Kong route after nearly 30 years?
# Virgin Atlantic announced the decision to drop its Hong Kong route in October 2022, after nearly 30 years of service.
# Where is ATR headquartered?
# ATR is headquartered in Toulouse, France.
# What percentage of Earth's surface is underlain by permafrost?
# Permafrost underlies about 24% of the exposed land area in the Northern Hemisphere. This accounts for approximately 16-18% of Earth's land surface overall. However, if considering Earth's entire surface, including oceans, the percentage of the Earth's total surface that is underlain by permafrost is smaller, roughly around 11-12%. These estimates can vary slightly depending on the source and the specific methods used for measurement.
# What is the refund policy for the Learn Enough tutorials?
# As of my last update, Learn Enough offers a 60-day full refund policy for their tutorials. If you are not satisfied with your purchase, you can request a refund within 60 days of your purchase date. It's always a good idea to check their official website or contact their customer support for the most current and detailed information regarding their refund policy.
# What is The Greek's relationship with Proposition Joe in 'The Wire'?
# In the television series "The Wire," The Greek is a shadowy figure involved in smuggling and organized crime, while Proposition Joe is a drug dealer in Baltimore. Their relationship is primarily business-oriented, with The Greek acting as a supplier for Proposition Joe. The Greek provides access to high-quality drugs, which Proposition Joe then distributes in Baltimore. This relationship is based on mutual benefit, as it allows Proposition Joe to maintain a steady supply of drugs and enables The Greek to profit from the local drug trade. Their interactions highlight the intricate connections between different layers of the criminal underworld depicted in the series.
# How many electorate seats did Te PÄti MÄori win in the 2023 New Zealand general election?
# In the 2023 New Zealand general election, Te Pāti Māori won four electorate seats.
# At what precise time on March 1, 1872, did President Ulysses S. Grant sign the Yellowstone National Park Protection Act, officially establishing Yellowstone as the world's first national park?
# The precise time at which President Ulysses S. Grant signed the Yellowstone National Park Protection Act on March 1, 1872, is not documented in historical records. While we know the date it was signed, records from that time do not provide an exact time of day for the signing.
# in which episode does omar little become mayor of baltimore
# Omar Little never becomes the mayor of Baltimore in *The Wire*. Omar is a fictional character from the television series, known for being a notorious stick-up man who robs drug dealers. The storyline of *The Wire*, which aired on HBO from 2002 to 2008, does not include any plot where Omar enters politics or becomes mayor. If you have further questions about the show, feel free to ask!
# kelly buchberger nhl draft year
# Kelly Buchberger was drafted in the 1985 NHL Entry Draft.
# What is the role of bacteriochlorophyll in anoxygenic photosynthesis performed by some bacteria?
# Bacteriochlorophyll plays a crucial role in anoxygenic photosynthesis performed by certain types of photosynthetic bacteria, such as purple bacteria, green sulfur bacteria, and heliobacteria. Unlike oxygenic photosynthesis in plants, algae, and cyanobacteria, which release oxygen as a byproduct, anoxygenic photosynthesis does not produce oxygen.
#
# Here are the key roles of bacteriochlorophyll in anoxygenic photosynthesis:
#
# 1. **Light Absorption**: Bacteriochlorophyll acts as a photosynthetic pigment, similar to chlorophyll in plants, but it has a distinct absorption spectrum, allowing it to capture light energy in different wavelengths. This adaptation is beneficial in environments with limited light or where chlorophyll-utilizing organisms dominate.
#
# 2. **Energy Transfer**: Once bacteriochlorophyll absorbs light energy, it helps transfer that energy through a series of reactions within the bacterial photosynthetic apparatus. This energy conversion is crucial for driving the photosynthetic electron transport chain.
#
# 3. **Electron Transport**: In anoxygenic photosynthesis, bacteriochlorophyll participates in the transfer of electrons, which ultimately are used to generate a proton gradient across the membrane. This is fundamental for ATP synthesis using ATP synthase.
#
# 4. **Carbon Fixation**: The energy and reducing power generated through the activities involving bacteriochlorophyll are utilized for carbon fixation, where inorganic carbon (usually carbon dioxide) is converted into organic compounds. Different bacteria might use various carbon fixation pathways such as the Calvin cycle or the reverse TCA cycle.
#
# 5. **Adaptation to Environment**: Bacteriochlorophylls have different types and forms (e.g., bacteriochlorophyll a, b, c) adapted for specific ecological niches, allowing these bacteria to occupy a variety of light environments and compete effectively with other organisms.
#
# Overall, bacteriochlorophyll is essential for capturing light energy and driving the biochemical processes that support the growth and survival of anoxygenic photosynthetic bacteria.
# how many russian aircraft did ukrainian f-16s shoot down on august 26
# As of my last update, there were no reports of Ukrainian F-16s shooting down Russian aircraft on August 26, 2023. It is possible that this is either misinformation or an event that was not captured in accessible data. Please check the latest news sources or official statements for the most current information.
# Which films were among the contenders for the 2024 PGA Awards?
# As of now, I don't have access to real-time information beyond October 2023, including the contenders for the 2024 Producers Guild of America (PGA) Awards. To find out the list of films contending for these awards, you may want to check the PGA's official announcements or reliable entertainment news sources closer to the event date.
# Who won the 2023 FIFA Women's World Cup?
# Spain won the 2023 FIFA Women's World Cup. They defeated England 1-0 in the final.
# In Amy Millan's third solo album 'Whiskey Lullabies', released between 'Honey from the Tombs' and 'Masters of the Burial', how did her experiences with Stars and Broken Social Scene influence the album's sound compared to her previous solo work?
# It appears there might be some confusion regarding Amy Millan's discography. Amy Millan's known solo albums are "Honey from the Tombs" (2006) and "Masters of the Burial" (2009). As of my latest update, there is no third solo album titled "Whiskey Lullabies" released by her.
#
# However, Amy Millan is a member of bands like Stars and Broken Social Scene, both of which have a distinct influence on her music. Stars is known for its lush, indie pop sound, while Broken Social Scene tends toward a more experimental and eclectic indie rock style. These influences are often reflected in her solo work, which balances rich, melodic storytelling with a more stripped-down, folk-inspired sound. "Honey from the Tombs" showcased this with intimate, personal songwriting and a blend of folk and indie pop. "Masters of the Burial" continued in that vein but with a more mature, refined approach, likely drawing from her evolving experiences in the collaborative and dynamic environments of both bands. If you have more information on a recent or lesser-known release, I could help analyze those elements instead.
# When was Alien: Romulus released in the United States?
# "Alien: Romulus" has not been released yet, and there is no official release date announced for the United States or any other region. It's best to check for the latest updates from official sources or trusted entertainment news outlets for any announcements regarding its release.
# What was the Boeing 747's nickname, and why was it significant in aviation history?
# The Boeing 747 was famously nicknamed the "Jumbo Jet." It holds significant importance in aviation history due to several factors:
#
# 1. **Size and Capacity**: When it was first introduced in 1969, the 747 was the largest commercial aircraft in the world. Its double-deck configuration and wide-body made it capable of carrying more passengers and cargo than any other airliner at the time. This capability effectively democratized air travel, making it more accessible to the masses.
#
# 2. **Range**: The 747 was able to fly long distances without refueling, facilitating non-stop intercontinental travel and opening up new global routes for airlines.
#
# 3. **Technology and Design**: The 747 featured advanced technology and innovative design elements for its time, including a distinctive hump on its upper deck which often housed a first-class lounge and provided additional passenger capacity.
#
# 4. **Economic Impact**: The increased passenger capacity and efficiency of the 747 helped lower the cost per seat mile for airlines, contributing to the rapid expansion of the global travel market.
#
# Overall, the Boeing 747 revolutionized air travel, setting new standards for size, efficiency, and range, and it became an iconic symbol of modern aviation.
# When was Yellowstone National Park established?
# Yellowstone National Park was established on March 1, 1872. It was the first national park in the United States and is often considered the first national park in the world.
# red dead redemption 2 missions in nuevo paraiso
# In "Red Dead Redemption 2," Nuevo Paraíso is a region in the game that players do not explore during the main storyline as Arthur Morgan, but it becomes accessible later in the game through the Epilogue.
#
# During the Epilogue, when you play as John Marston, you return to several familiar locations and get involved in activities that extend beyond the main story of Arthur Morgan. However, Nuevo Paraíso, the Mexican location featured in the original "Red Dead Redemption," is not actually traversable or part of the main missions in "Red Dead Redemption 2."
#
# If you're interested in reasons to explore beyond the regular missions, you may want to consider single-player mods on PC, which some players use to experience different parts of the map that are otherwise not accessible, including Nuevo Paraíso. Keep in mind that such modifications are unofficial and come with their own risks.
#
# In the official storyline and available missions from Rockstar Games, there's no mission content in Nuevo Paraíso in "Red Dead Redemption 2." This area is more of a memory nod for fans of the series and is fully playable in the original "Red Dead Redemption" game.
# What are the risk factors for developing tendinitis?
# Tendinitis, which is the inflammation or irritation of a tendon, can be influenced by several risk factors. These include:
#
# 1. **Age**: As people age, tendons become less flexible and more prone to injury.
#
# 2. **Repetitive Motion**: Activities that involve repetitive motion or exertion, such as typing, playing certain sports, or doing manual labor, can increase the risk of tendinitis.
#
# 3. **Improper Technique**: Using incorrect techniques in sports or physical activities can place excessive strain on tendons.
#
# 4. **Sudden Increase in Activity Level**: Rapidly increasing the intensity or frequency of physical activity without proper preparation can lead to tendinitis.
#
# 5. **Occupational Factors**: Jobs that involve repetitive motions, awkward positions, or overhead reaching can contribute to tendinitis.
#
# 6. **Sports Participation**: Engaging in certain sports like tennis, golf, baseball, and running, which require repetitive movements, can increase risk.
#
# 7. **Poor Posture**: Consistently maintaining poor posture can place additional stress on tendons.
#
# 8. **Medical Conditions**: Conditions such as rheumatoid arthritis, gout, and diabetes can predispose individuals to tendinitis.
#
# 9. **Inadequate Conditioning**: Lack of proper warm-up or stretching exercises can increase the likelihood of tendon injury.
#
# 10. **Previous Injuries**: A history of tendon injuries may increase the risk of developing tendinitis again in the same area.
#
# 11. **Foot Mechanics**: Abnormalities such as flat feet can place abnormal strain on tendons in the ankle and foot.
#
# Understanding these risk factors can help in taking preventive measures and reducing the likelihood of developing tendinitis. If you're at risk, it's important to focus on appropriate stretching, conditioning, and using the right techniques and equipment for activities.
# What was Warner Brothers' highest grossing movie of 1973?
# Warner Bros.' highest-grossing movie of 1973 was "Enter the Dragon." This martial arts action film starred Bruce Lee and became a major box office success, solidifying Lee's status as a global icon.
# What was the impact of the Soviet attack on Manchuria on Japan's surrender in WWII?
# The Soviet attack on Manchuria in August 1945 had a significant impact on Japan's decision to surrender in World War II. This operation, known as the Soviet invasion of Manchuria, was a massive military campaign by the Soviet Union against Japanese forces in the region. Here are some key points regarding its impact:
#
# 1. **Strategic Shock**: The Soviet invasion was a surprise to Japan, as the Soviet Union had maintained a neutrality pact with Japan since 1941. The sudden attack shattered any Japanese hopes of negotiating a better surrender deal through Soviet mediation.
#
# 2. **Military Devastation**: The Red Army launched a well-coordinated, multi-pronged assault, quickly overwhelming the Japanese Kwantung Army, which was already weakened and poorly equipped. The sheer speed and effectiveness of the Soviet advance demonstrated that Japan could not withstand a two-front war involving both the United States and the Soviet Union.
#
# 3. **Political Factors**: The initiative undermined Japan's internal political situation. The Japanese military and government had dwindling options, as the Soviet entry into the war eliminated any realistic hopes of surviving the conflict or negotiating favorable terms.
#
# 4. **Catalyst for Surrender**: Combined with the effects of the atomic bombings of Hiroshima on August 6 and Nagasaki on August 9, the Soviet invasion contributed to the Japanese leadership's decision to surrender. The dual threat from the atomic bombings and Soviet advance created a sense of urgency and hopelessness among Japanese leaders.
#
# 5. **End of Japanese Expansion in Asia**: The quick and decisive Soviet victories helped dismantle Japanese control over its occupied territories in Asia, particularly in China and Korea, thereby accelerating Japan's military and imperial retreat.
#
# In conclusion, the Soviet attack on Manchuria was a crucial factor in Japan's surrender, alongside other events like the atomic bombings. It demonstrated that Japan was strategically and militarily outmatched, hastening the end of World War II in the Pacific.
# What is the Palace of Versailles known for?
# The Palace of Versailles is renowned for its historical significance, opulent architecture, and extensive gardens. Initially a hunting lodge, it was transformed and expanded in the 17th century under the reign of King Louis XIV into a symbol of absolute monarchy and royal extravagance. The palace is known for its grandiose design, intricate interior decorations—including the Hall of Mirrors—and luxurious furnishings.
#
# Beyond its architectural splendor, the Palace of Versailles is also famous for its role in significant historical events, such as the signing of the Treaty of Versailles in 1919, which ended World War I. The expansive gardens, designed by landscape architect André Le Nôtre, feature meticulously manicured lawns, ornate fountains, and a network of paths and canals. The palace and its gardens are UNESCO World Heritage sites, attracting millions of visitors each year who come to experience its beauty and historical legacy.
# emma watson vanity fair controvercy feminism
# The controversy surrounding Emma Watson and Vanity Fair originated in March 2017, when the magazine published a photo of Watson wearing a sheer, white capelet that partially revealed her breasts. The photo was part of a larger feature on her, accompanied by an interview.
#
# The image sparked a debate, as some critics argued that it was hypocritical for Watson to pose for such a revealing photograph while also being a prominent advocate for feminism and gender equality. Critics claimed that her choice to pose in this way conflicted with her feminist values.
#
# In response to the backlash, Watson defended her decision, emphasizing that feminism is about freedom, choice, and equality rather than prescribing how women should dress or behave. She argued that feminism is not a "stick with which to beat other women" and stressed that it is about giving women the freedom to make their own choices.
#
# The controversy highlighted ongoing discussions about the intersection of feminism, personal autonomy, and the portrayal of women in media. Watson's response underscored a broader conversation about how feminism can encompass various forms of expression and individuality.
# What is the money-back guarantee period for Learn Enough tutorials?
# Learn Enough tutorials come with a 60-day money-back guarantee. If you're not satisfied with your purchase, you can request a refund within this period. Be sure to check their official website or contact their customer support for the most current and specific details regarding their refund policy.
# How many people were injured in the Dollywood park flooding?
# There are no reports of a flooding incident at Dollywood that resulted in injuries. Please verify if this is recent news or if there might be some misunderstanding regarding the location or event.
# How many Grand Slam titles did Roger Federer win in his career?
# Roger Federer won 20 Grand Slam singles titles in his career.
# which croatian city replaced malta for filming king's landing scenes starting season 2
# Starting in Season 2 of "Game of Thrones," the Croatian city of Dubrovnik replaced Malta as the primary filming location for King's Landing. Dubrovnik's medieval architecture and coastal setting provided the perfect backdrop for the fictional capital of Westeros.
# rust borrow checker prevent sql injection attacks
# Rust's borrow checker is primarily a tool for ensuring memory safety and preventing issues like data races and invalid memory access by enforcing strict rules about how references to data are used. While it is a powerful feature for managing memory safety, it does not directly address SQL injection attacks, which are a type of security vulnerability arising from improper handling of user input in SQL queries.
#
# To prevent SQL injection attacks in Rust, you'll need to use safe practices for handling SQL queries, particularly when incorporating user input. Here are some strategies you can employ in Rust to mitigate the risk of SQL injections:
#
# 1. **Parameterized Queries**: Use parameterized queries or prepared statements whenever possible. Most database libraries in Rust provide support for this. By using parameterized queries, you can safely include user input in your SQL statements without risking SQL injection attacks. Libraries like `diesel` and `tokio-postgres` support this functionality.
#
#     ```rust
#     use postgres::{Client, NoTls};
#
#     let mut client = Client::connect("host=localhost user=postgres", NoTls)?;
#
#     // Safely include user input into the query
#     client.execute(
#         "INSERT INTO users (name, email) VALUES ($1, $2)",
#         &[&user_name, &user_email],
#     )?;
#     ```
#
# 2. **ORM Libraries**: Consider utilizing object-relational mapping (ORM) libraries like Diesel, which can abstract away a lot of raw SQL and use Rust’s type system to build queries safely, reducing the risk of SQL injection.
#
#     ```rust
#     use diesel::prelude::*;
#     use my_project::models::{NewUser, User};
#
#     let new_user = NewUser {
#         name: user_name,
#         email: user_email,
#     };
#
#     diesel::insert_into(users::table)
#         .values(&new_user)
#         .execute(&connection)?;
#     ```
#
# 3. **Input Validation and Sanitization**: Although parameterized queries are the most effective way to prevent SQL injection, it is also good practice to validate and sanitize inputs. Ensure that any user input conforms to expected formats before processing.
#
# 4. **Least Privilege Principle**: Configure your database user accounts to have the least amount of privileges necessary. This limits the damage in case of an injection vulnerability.
#
# 5. **Regular Security Audits**: Conduct regular reviews and audits of your code for potential vulnerabilities. Security best practices evolve, and staying up-to-date can help protect against new threats.
#
# While the Rust borrow checker plays a crucial role in ensuring memory safety, preventing SQL injections relies on the correct handling of external data and using safe, established methods for executing database queries.

# %% [markdown]
# You can repeat this process with different agent configurations such as:
# - Models (gpt-5.1, gpt-5-mini, etc.)
# - Prompts
# - Tools (search vs. no search)
# - Complexity of agent (multi agent vs single agent)
#
# Then compare them side-by-side in Langfuse. In this example, I did run the agent 3 times on the 30 dataset questions. For each run, I used a different OpenAI model. You can see that amount of correctly answered questions improves when using a larger model (as expected). The `correct_answer` score is created by an [LLM-as-a-Judge Evaluator](https://langfuse.com/docs/scores/model-based-evals) that is set up to judge the correctness of the question based on the sample answer given in the dataset.
#
# ![Dataset run overview](https://langfuse.com/images/cookbook/example-langgraph-evaluation/dataset_runs.png)
# ![Dataset run comparison](https://langfuse.com/images/cookbook/example-langgraph-evaluation/dataset-run-comparison.png)

# %%
# !pip install crewai langfuse
# !pip install 'crewai[tools]'
# Out:
# Requirement already satisfied: crewai in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (0.28.8)
# Requirement already satisfied: langfuse in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (2.26.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (1.4.4)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (8.1.7)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.98 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (0.1.102)
# Requirement already satisfied: instructor<0.6.0,>=0.5.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (0.5.2)
# Requirement already satisfied: langchain<0.2.0,>=0.1.10 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (0.1.16)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (1.20.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (1.24.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (1.24.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (2.7.0)
# Requirement already satisfied: python-dotenv==1.0.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (1.0.0)
# Requirement already satisfied: regex<2024.0.0,>=2023.12.25 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai) (2023.12.25)
# Requirement already satisfied: backoff<3.0.0,>=2.2.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langfuse) (2.2.1)
# Requirement already satisfied: httpx<1.0,>=0.15.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langfuse) (0.27.0)
# Requirement already satisfied: idna<4.0,>=3.7 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langfuse) (3.7)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langfuse) (23.2)
# Requirement already satisfied: wrapt<2.0,>=1.14 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langfuse) (1.16.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (1.13.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (4.12.3)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.17 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.4.24)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (1.48.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.1.43)
# Requirement already satisfied: langchain-openai<0.0.6,>=0.0.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.0.5)
# Requirement already satisfied: posthog<4.0.0,>=3.0.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (3.5.0)
# Requirement already satisfied: pypdf<4.0.0,>=3.11.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (3.17.4)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.3.4)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (13.7.1)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.7.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (2.0.29)
# Requirement already satisfied: tiktoken<0.6.0,>=0.5.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.5.2)
# Requirement already satisfied: anyio in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from httpx<1.0,>=0.15.4->langfuse) (4.3.0)
# Requirement already satisfied: certifi in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from httpx<1.0,>=0.15.4->langfuse) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from httpx<1.0,>=0.15.4->langfuse) (1.0.5)
# Requirement already satisfied: sniffio in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from httpx<1.0,>=0.15.4->langfuse) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0,>=0.15.4->langfuse) (0.14.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai) (3.9.4)
# Requirement already satisfied: docstring-parser<0.16,>=0.15 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai) (0.15)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai) (8.2.3)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai) (0.9.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai) (6.0.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.32 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai) (0.0.34)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.42 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai) (0.1.45)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai) (0.1.49)
# Requirement already satisfied: numpy<2,>=1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai) (2.31.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: tqdm>4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai) (4.11.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.24.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-proto==1.24.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (4.25.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai) (0.45b0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.2->crewai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.2->crewai) (2.18.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai) (1.9.4)
# Requirement already satisfied: Mako in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.98->crewai) (1.3.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain<0.2.0,>=0.1.98->crewai) (2.5)
# Requirement already satisfied: build>=1.0.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.109.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.22.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.17.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.45b0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.62.2)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (4.1.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (3.10.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (2.18.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (2.29.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (1.23.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (2.16.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (3.21.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (1.12.3)
# Requirement already satisfied: shapely<3.0.0dev in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (2.0.4)
# Requirement already satisfied: cachetools in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from gptcache<0.2.0,>=0.1.43->embedchain<0.2.0,>=0.1.98->crewai) (5.3.3)
# Requirement already satisfied: zipp>=0.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api<2.0.0,>=1.22.0->crewai) (3.18.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain<0.2.0,>=0.1.10->crewai) (2.4)
# Requirement already satisfied: six>=1.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai) (1.6)
# Requirement already satisfied: python-dateutil>2.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.10->crewai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.10->crewai) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai) (2.17.2)
# Requirement already satisfied: contextlib2>=0.5.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from schema<0.8.0,>=0.7.5->embedchain<0.2.0,>=0.1.98->crewai) (21.6.0)
# Requirement already satisfied: pyproject_hooks in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.0.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.36.3)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (1.62.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (2.7.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (0.13.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (1.5.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (3.2.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai) (0.1.2)
# Requirement already satisfied: coloredlogs in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (24.3.25)
# Requirement already satisfied: sympy in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.12)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (69.5.1)
# Requirement already satisfied: asgiref~=3.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (3.8.1)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.22.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (12.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from Mako->alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.98->crewai) (2.1.5)
# Requirement already satisfied: filelock in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (2024.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (0.6.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.3.0)
# Requirement already satisfied: crewai[tools] in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (0.28.8)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (1.4.4)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (8.1.7)
# Requirement already satisfied: crewai-tools<0.2.0,>=0.1.7 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (0.1.7)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.98 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (0.1.102)
# Requirement already satisfied: instructor<0.6.0,>=0.5.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (0.5.2)
# Requirement already satisfied: langchain<0.2.0,>=0.1.10 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (0.1.16)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (1.20.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (1.24.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (1.24.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (2.7.0)
# Requirement already satisfied: python-dotenv==1.0.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (1.0.0)
# Requirement already satisfied: regex<2024.0.0,>=2023.12.25 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai[tools]) (2023.12.25)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (4.12.3)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.22 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.4.24)
# Requirement already satisfied: lancedb<0.6.0,>=0.5.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.5.7)
# Requirement already satisfied: pyright<2.0.0,>=1.1.350 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.1.359)
# Requirement already satisfied: pytest<9.0.0,>=8.0.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (8.1.1)
# Requirement already satisfied: pytube<16.0.0,>=15.0.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (15.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.31.0)
# Requirement already satisfied: selenium<5.0.0,>=4.18.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (4.19.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.13.1)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.48.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.1.43)
# Requirement already satisfied: langchain-openai<0.0.6,>=0.0.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.0.5)
# Requirement already satisfied: posthog<4.0.0,>=3.0.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (3.5.0)
# Requirement already satisfied: pypdf<4.0.0,>=3.11.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (3.17.4)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.3.4)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (13.7.1)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.7.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.0.29)
# Requirement already satisfied: tiktoken<0.6.0,>=0.5.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.5.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai[tools]) (3.9.4)
# Requirement already satisfied: docstring-parser<0.16,>=0.15 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai[tools]) (0.15)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai[tools]) (8.2.3)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai[tools]) (0.9.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (6.0.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.32 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (0.0.34)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.42 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (0.1.45)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (0.1.49)
# Requirement already satisfied: numpy<2,>=1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (1.26.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (0.27.0)
# Requirement already satisfied: sniffio in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (4.11.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai[tools]) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai[tools]) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (1.24.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-proto==1.24.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (4.25.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai[tools]) (0.45b0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.2->crewai[tools]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.2->crewai[tools]) (2.18.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai[tools]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai[tools]) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai[tools]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai[tools]) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai[tools]) (1.9.4)
# Requirement already satisfied: Mako in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.3.3)
# Requirement already satisfied: idna>=2.8 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.13.3->crewai[tools]) (3.7)
# Requirement already satisfied: soupsieve>1.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.5)
# Requirement already satisfied: build>=1.0.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.109.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.22.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.17.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.45b0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.62.2)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (4.1.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.10.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai[tools]) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai[tools]) (0.9.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.22.0->crewai[tools]) (1.16.0)
# Requirement already satisfied: PyGithub<2.0.0,>=1.59.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.59.1)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.38 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.1.43)
# Requirement already satisfied: youtube-transcript-api<0.7.0,>=0.6.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.6.2)
# Requirement already satisfied: yt_dlp<2024.0.0,>=2023.11.14 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2023.12.30)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.18.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.29.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.23.0)
# Requirement already satisfied: packaging>=14.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (23.2)
# ...
# Requirement already satisfied: retry>=0.9.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.9.2)
# Requirement already satisfied: semver>=3.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.0.2)
# Requirement already satisfied: pyarrow>=12 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pylance==0.9.18->lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (16.0.0)
# Requirement already satisfied: six>=1.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.9.0.post0)
# Requirement already satisfied: nodeenv>=1.6.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pyright<2.0.0,>=1.1.350->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.8.0)
# Requirement already satisfied: iniconfig in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pytest<9.0.0,>=8.0.0->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=1.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pytest<9.0.0,>=8.0.0->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai[tools]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.17.2)
# Requirement already satisfied: contextlib2>=0.5.5 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from schema<0.8.0,>=0.7.5->embedchain<0.2.0,>=0.1.98->crewai[tools]) (21.6.0)
# Requirement already satisfied: trio~=0.17 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.11.1)
# Requirement already satisfied: pyproject_hooks in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.0.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.36.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from gitpython<4.0.0,>=3.1.38->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (4.0.11)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.62.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.7.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.13.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.5.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.2.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.1.2)
# Requirement already satisfied: setuptools in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from nodeenv>=1.6.0->pyright<2.0.0,>=1.1.350->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (69.5.1)
# Requirement already satisfied: coloredlogs in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (24.3.25)
# Requirement already satisfied: sympy in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.12)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.45b0)
# Requirement already satisfied: asgiref~=3.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.8.1)
# Requirement already satisfied: pyjwt>=2.4.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.8.0)
# Requirement already satisfied: pynacl>=1.4.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.5.0)
# Requirement already satisfied: decorator>=3.4.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.11.0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.22.2)
# Requirement already satisfied: sortedcontainers in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from trio~=0.17->selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.4.0)
# Requirement already satisfied: outcome in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from trio~=0.17->selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai[tools]) (1.0.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.7.1)
# Requirement already satisfied: httptools>=0.5.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (12.0)
# Requirement already satisfied: mutagen in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from yt_dlp<2024.0.0,>=2023.11.14->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.47.0)
# Requirement already satisfied: pycryptodomex in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from yt_dlp<2024.0.0,>=2023.11.14->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.20.0)
# Requirement already satisfied: brotli in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from yt_dlp<2024.0.0,>=2023.11.14->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from Mako->alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.1.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.38->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (5.0.1)
# Requirement already satisfied: filelock in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2024.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.6.0)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (42.0.5)
# Requirement already satisfied: cffi>=1.4.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from pynacl>=1.4.0->PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.3.0)
# Requirement already satisfied: pycparser in /Users/richardkruemmel/Code/langfuse-docs/.venv/lib/python3.12/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.22)

# %%
import os
from langfuse.openai import auth_check

os.environ["LANGFUSE_PUBLIC_KEY"] = ""
os.environ["LANGFUSE_SECRET_KEY"] = ""
os.environ["OPENAI_API_KEY"] = ""
 
auth_check()
# Out:
# True

# %%
from crewai import Agent


# Creating a senior researcher agent with memory and verbose mode

researcher = Agent(
  role='Senior Researcher',
  goal='Uncover groundbreaking technologies in {topic}',
  verbose=True,
  memory=True,
  backstory=(
    "Driven by curiosity, you're at the forefront of"
    "innovation, eager to explore and share knowledge that could change"
    "the world."
  ),
  tools=[search_tool],
  allow_delegation=True
)



# Creating a writer agent with custom tools and delegation capability

writer = Agent(
  role='Writer',
  goal='Narrate compelling tech stories about {topic}',
  verbose=True,
  memory=True,
  backstory=(
    "With a flair for simplifying complex topics, you craft"
    "engaging narratives that captivate and educate, bringing new"
    "discoveries to light in an accessible manner."
  ),
  tools=[search_tool],
  allow_delegation=False
)
